# %%
import math

# %%
math.cos(1)
# Out:
# 0.5403023058681397

# %%
from math import pi, cos

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'pi',
#  'pow',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc']

# %%
help(math)
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module is always available.  It provides access to the
#     mathematical functions defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     ceil(x, /)
#         Return the ceiling of x as an Integral.
#
#         This is the smallest integer >= x.
#
#     copysign(x, y, /)
# ...

# %%
import math

# %%
math.sqrt(4)
# Out:
# 2.0

# %%
import random

# %%
from random import randrange

# %%
help(random)
# Out:
# Help on module random:
#
# NAME
#     random - Random variable generators.
#
# DESCRIPTION
#         integers
#         --------
#                uniform within range
#
#         sequences
#         ---------
#                pick random element
#                pick random sample
#                pick weighted random sample
#                generate random permutation
#
#         distributions on the real line:
#         ------------------------------
#                uniform
#                triangular
#                normal (Gaussian)
#                lognormal
#                negative exponential
#                gamma
#                beta
#                pareto
#                Weibull
#
#         distributions on the circle (angles 0 to 2pi)
#         ---------------------------------------------
#                circular uniform
#                von Mises
#
#     General notes on the underlying Mersenne Twister core generator:
#
#     * The period is 2**19937-1.
# ...

# %%
bases = 'ACTTGCTTGAC'

# %%
import pandas

data = pandas.read_csv('gapminder_gdp_oceania.csv' , index_col='country')
print(data)
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Australia       10039.59564     10949.64959     12217.22686     14526.12465
# New Zealand     10556.57566     12247.39532     13175.67800     14463.91893
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Australia       16788.62948     18334.19751     19477.00928     21888.88903
# New Zealand     16046.03728     16233.71770     17632.41040     19007.19129
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Australia       23424.76683     26997.93657     30687.75473     34435.36744
# New Zealand     18363.32494     21050.41377     23189.80135     25185.00911

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, Australia to New Zealand
# Data columns (total 12 columns):
# gdpPercap_1952    2 non-null float64
# gdpPercap_1957    2 non-null float64
# gdpPercap_1962    2 non-null float64
# gdpPercap_1967    2 non-null float64
# gdpPercap_1972    2 non-null float64
# gdpPercap_1977    2 non-null float64
# gdpPercap_1982    2 non-null float64
# gdpPercap_1987    2 non-null float64
# gdpPercap_1992    2 non-null float64
# gdpPercap_1997    2 non-null float64
# gdpPercap_2002    2 non-null float64
# gdpPercap_2007    2 non-null float64
# dtypes: float64(12)
# memory usage: 208.0+ bytes

# %%
print(data.columns)
# Out:
# Index(['gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962', 'gdpPercap_1967',
#        'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982', 'gdpPercap_1987',
#        'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002', 'gdpPercap_2007'],
#       dtype='object')

# %%
print(data.T)
# Out:
# country           Australia  New Zealand
# gdpPercap_1952  10039.59564  10556.57566
# gdpPercap_1957  10949.64959  12247.39532
# gdpPercap_1962  12217.22686  13175.67800
# gdpPercap_1967  14526.12465  14463.91893
# gdpPercap_1972  16788.62948  16046.03728
# gdpPercap_1977  18334.19751  16233.71770
# gdpPercap_1982  19477.00928  17632.41040
# gdpPercap_1987  21888.88903  19007.19129
# gdpPercap_1992  23424.76683  18363.32494
# gdpPercap_1997  26997.93657  21050.41377
# gdpPercap_2002  30687.75473  23189.80135
# gdpPercap_2007  34435.36744  25185.00911

# %%
print(data.describe)
# Out:
# <bound method NDFrame.describe of              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Australia       10039.59564     10949.64959     12217.22686     14526.12465
# New Zealand     10556.57566     12247.39532     13175.67800     14463.91893
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Australia       16788.62948     18334.19751     19477.00928     21888.88903
# New Zealand     16046.03728     16233.71770     17632.41040     19007.19129
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Australia       23424.76683     26997.93657     30687.75473     34435.36744
# New Zealand     18363.32494     21050.41377     23189.80135     25185.00911  >

# %%
print(data.describe())
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count        2.000000        2.000000        2.000000        2.000000
# mean     10298.085650    11598.522455    12696.452430    14495.021790
# std        365.560078      917.644806      677.727301       43.986086
# min      10039.595640    10949.649590    12217.226860    14463.918930
# 25%      10168.840645    11274.086022    12456.839645    14479.470360
# 50%      10298.085650    11598.522455    12696.452430    14495.021790
# 75%      10427.330655    11922.958888    12936.065215    14510.573220
# max      10556.575660    12247.395320    13175.678000    14526.124650
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count         2.00000        2.000000        2.000000        2.000000
# mean      16417.33338    17283.957605    18554.709840    20448.040160
# std         525.09198     1485.263517     1304.328377     2037.668013
# ...

# %%
americas = pandas.read_csv('gapminder_gdp_americas.csv', index_col='country')

# %%
print(americas.describe())
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count       25.000000       25.000000       25.000000       25.000000
# mean      4079.062552     4616.043733     4901.541870     5668.253496
# std       3001.727522     3312.381083     3421.740569     4160.885560
# min       1397.717137     1544.402995     1662.137359     1452.057666
# 25%       2428.237769     2487.365989     2750.364446     3242.531147
# 50%       3048.302900     3780.546651     4086.114078     4643.393534
# 75%       3939.978789     4756.525781     5180.755910     5788.093330
# max      13990.482080    14847.127120    16173.145860    19530.365570
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count       25.000000       25.000000       25.000000       25.000000
# mean      6491.334139     7352.007126     7506.737088     7793.400261
# std       4754.404329     5355.602518     5530.490471     6665.039509
# ...

# %%
americas.T.iloc[1:,:].astype(float)
# Out:
# country     Argentina      Bolivia       Brazil        Canada         Chile  \
# count       12.000000    12.000000    12.000000     12.000000     12.000000
# mean      8955.553783  2961.228754  5829.316653  22410.746340   6703.289147
# std       1862.583151   524.748706  2436.453754   8210.112789   3026.194023
# min       5911.315053  2127.686326  2108.944355  11367.161120   3939.978789
# 25%       7823.006271  2654.716273  3406.544718  15423.062410   4697.346460
# 50%       9068.784401  2971.015516  6805.200837  22494.837600   5300.339375
# 75%       9602.035579  3347.923066  7844.817069  27208.617745   8226.607768
# max      12779.379640  3822.137084  9065.800825  36319.235010  13171.638850
#
# country     Colombia   Costa Rica         Cuba  Dominican Republic  \
# count      12.000000    12.000000    12.000000           12.000000
# mean     4195.342920  5448.610779  6283.258678         2844.856405
# std      1652.931466  2018.532901  1127.781072         1373.906233
# ...

# %%
americas
# Out:
# country            Argentina      Bolivia       Brazil       Canada  \
# gdpPercap_1952   5911.315053  2677.326347  2108.944355  11367.16112
# gdpPercap_1957   6856.856212  2127.686326  2487.365989  12489.95006
# gdpPercap_1962   7133.166023  2180.972546  3336.585802  13462.48555
# gdpPercap_1967   8052.953021  2586.886053  3429.864357  16076.58803
# gdpPercap_1972   9443.038526  2980.331339  4985.711467  18970.57086
# gdpPercap_1977  10079.026740  3548.097832  6660.118654  22090.88306
# gdpPercap_1982   8997.897412  3156.510452  7030.835878  22898.79214
# gdpPercap_1987   9139.671389  2753.691490  7807.095818  26626.51503
# gdpPercap_1992   9308.418710  2961.699694  6950.283021  26342.88426
# gdpPercap_1997  10967.281950  3326.143191  7957.980824  28954.92589
# gdpPercap_2002   8797.640716  3413.262690  8131.212843  33328.96507
# gdpPercap_2007  12779.379640  3822.137084  9065.800825  36319.23501
#
# country                Chile     Colombia   Costa Rica         Cuba  \
# ...

# %%
americas = americas.T.iloc[1:,:].astype(float)
americas

# %%
americas.iloc[0,0]
# Out:
# 5911.315053

# %%
americas.columns
# Out:
# Index(['Argentina', 'Bolivia', 'Brazil', 'Canada', 'Chile', 'Colombia',
#        'Costa Rica', 'Cuba', 'Dominican Republic', 'Ecuador', 'El Salvador',
#        'Guatemala', 'Haiti', 'Honduras', 'Jamaica', 'Mexico', 'Nicaragua',
#        'Panama', 'Paraguay', 'Peru', 'Puerto Rico', 'Trinidad and Tobago',
#        'United States', 'Uruguay', 'Venezuela'],
#       dtype='object', name='country')

# %%
americas.loc[:, "Argentina"]
# Out:
# gdpPercap_1952     5911.315053
# gdpPercap_1957     6856.856212
# gdpPercap_1962     7133.166023
# gdpPercap_1967     8052.953021
# gdpPercap_1972     9443.038526
# gdpPercap_1977    10079.026740
# gdpPercap_1982     8997.897412
# gdpPercap_1987     9139.671389
# gdpPercap_1992     9308.418710
# gdpPercap_1997    10967.281950
# gdpPercap_2002     8797.640716
# gdpPercap_2007    12779.379640
# Name: Argentina, dtype: float64

# %%
import pandas as pd
africa_gdp_df = pd.read_csv("gapminder_gdp_africa.csv", index_col='country')
africa_gdp_df = africa_gdp_df.T

import matplotlib.pyplot as plt
plt.matshow(africa_gdp_df.corr())
africa_gdp_df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_ab0aed7e_735f_11e9_a478_b2e969045509row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_ab0aed7e_735f_11e9_a478_b2e969045509row0_col1 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_ab0aed7e_735f_11e9_a478_b2e969045509row0_col2 {
#             background-color:  #d0473d;
#             color:  #f1f1f1;
#         }    #T_ab0aed7e_735f_11e9_a478_b2e969045509row0_col3 {
#             background-color:  #d65244;
#             color:  #000000;
#         }    #T_ab0aed7e_735f_11e9_a478_b2e969045509row0_col4 {
#             background-color:  #d85646;
#             color:  #000000;
#         }    #T_ab0aed7e_735f_11e9_a478_b2e969045509row0_col5 {
#             background-color:  #ea7b60;
#             color:  #000000;
#         }    #T_ab0aed7e_735f_11e9_a478_b2e969045509row0_col6 {
#             background-color:  #d0473d;
#             color:  #f1f1f1;
# ...

# %%
import matplotlib.pyplot as plt

time=[0, 1, 2, 3]

# %%
position = [0, 100, 200, 300]

# %%
plt.plot(time, position)

# %%
import pandas
data = pandas.read_csv("gapminder_gdp_oceania.csv")

# %%
data
# Out:
#        country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0    Australia     10039.59564     10949.64959     12217.22686
# 1  New Zealand     10556.57566     12247.39532     13175.67800
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0     14526.12465     16788.62948     18334.19751     19477.00928
# 1     14463.91893     16046.03728     16233.71770     17632.41040
#
#    gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# 0     21888.88903     23424.76683     26997.93657     30687.75473
# 1     19007.19129     18363.32494     21050.41377     23189.80135
#
#    gdpPercap_2007
# 0     34435.36744
# 1     25185.00911

# %%
years = data.columns.str.strip('gdpPercap_')

# %%
data.columns.str.strip('gdpPercap_')
# Out:
# Index(['ountry', '1952', '1957', '1962', '1967', '1972', '1977', '1982',
#        '1987', '1992', '1997', '2002', '2007'],
#       dtype='object')

# %%
years
# Out:
# Index(['ountry', '_1952', '_1957', '_1962', '_1967', '_1972', '_1977', '_1982',
#        '_1987', '_1992', '_1997', '_2002', '_2007'],
#       dtype='object')

# %%
data
# Out:
#        country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0    Australia     10039.59564     10949.64959     12217.22686
# 1  New Zealand     10556.57566     12247.39532     13175.67800
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0     14526.12465     16788.62948     18334.19751     19477.00928
# 1     14463.91893     16046.03728     16233.71770     17632.41040
#
#    gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# 0     21888.88903     23424.76683     26997.93657     30687.75473
# 1     19007.19129     18363.32494     21050.41377     23189.80135
#
#    gdpPercap_2007
# 0     34435.36744
# 1     25185.00911

# %%
data_all = pandas.read_csv('gapminder_all.csv', index_col='country')
data_all.plot(kind='scatter', x='gdpPercap_2007', y='lifeExp_2007',
              s=data_all['pop_2007']/1e6)

# %%
import matplotlib.pyplot as plt

data_europe = pandas.read_csv('gapminder_gdp_europe.csv', index_col='country')
data_europe.min().plot(label='min')
data_europe.max().plot(label='max')
plt.legend(loc='best')
plt.xticks(rotation=90)
# Out:
# (array([ 0.,  2.,  4.,  6.,  8., 10., 12.]),
#  <a list of 7 Text xticklabel objects>)

# %%
import matplotlib.pyplot as plt

data_asia = pandas.read_csv('gapminder_gdp_asia.csv', index_col='country')
data_asia.describe().T.plot(kind='scatter', x='min', y='max')

# %%
plt.savefig('my_figure.png')

# %%
name = "trang"

# %%
name[1]
# Out:
# 'r'

# %%
name[2]
# Out:
# 'a'

# %%
name[3]
# Out:
# 'n'

# %%
primes = [1,3, 5, 7, 9, 11]

# %%
primes
# Out:
# [1, 3, 5, 7, 9, 11]

# %%
primes[4]
# Out:
# 9

# %%
primes.append(17)

# %%
primes
# Out:
# [1, 3, 5, 7, 9, 11, 17]

# %%
del primes[1]

# %%
primes
# Out:
# [1, 7, 9, 11, 17]

# %%
name[2]
# Out:
# 'a'

# %%
values = []

# %%
values.append(1)

# %%
values.append(3)

# %%
values.append(5)

# %%
print(values)
# Out:
# [1, 3, 5]

# %%
values[1:]
# Out:
# [3, 5]

# %%
for number in primes:
     print(number)
# Out:
# 1
# 7
# 9
# 11
# 17

# %%
primes
# Out:
# [1, 7, 9, 11, 17]

# %%
number = 2
print(number)
number = 3
print(number)
# Out:
# 2
# 3

# %%
for p in primes:
    print(p)
    print("still going")
    print ("all done")
# Out:
# 1
# still going
# all done
# 7
# still going
# all done
# 9
# still going
# all done
# 11
# still going
# all done
# 17
# still going
# all done

# %%
for p in primes: 
    print(p)
    print("still going")
print("all done")
# Out:
# 1
# still going
# 7
# still going
# 9
# still going
# 11
# still going
# 17
# still going
# all done

# %%
primes
# Out:
# [1, 7, 9, 11, 17]

# %%
total = 0
for p in primes:
    total = total + p
    print("running total is now", total)
average = total / len(primes)
print(average)
# Out:
# running total is now 1
# running total is now 8
# running total is now 17
# running total is now 28
# running total is now 45
# 9.0

# %%
average = total / len(primes)
print(average)
# Out:
# 9.0

# %%
sum(primes)
# Out:
# 45

# %%
import pandas 
for filename in ['gapminder_gdp_africa.csv', 'gapminder_gdp_asia.csv']:
    data = pandas.read_csv(filename, index_col='country')
    print(filename, data.min())
# Out:
# gapminder_gdp_africa.csv gdpPercap_1952    298.846212
# gdpPercap_1957    335.997115
# gdpPercap_1962    355.203227
# gdpPercap_1967    412.977514
# gdpPercap_1972    464.099504
# gdpPercap_1977    502.319733
# gdpPercap_1982    462.211415
# gdpPercap_1987    389.876185
# gdpPercap_1992    410.896824
# gdpPercap_1997    312.188423
# gdpPercap_2002    241.165877
# gdpPercap_2007    277.551859
# dtype: float64
# gapminder_gdp_asia.csv gdpPercap_1952    331.0
# gdpPercap_1957    350.0
# gdpPercap_1962    388.0
# gdpPercap_1967    349.0
# gdpPercap_1972    357.0
# gdpPercap_1977    371.0
# gdpPercap_1982    424.0
# gdpPercap_1987    385.0
# gdpPercap_1992    347.0
# gdpPercap_1997    415.0
# gdpPercap_2002    611.0
# gdpPercap_2007    944.0
# dtype: float64

# %%
import glob
print ('all csv files in data directory:', glob.glob('*.csv'))
# Out:
# all csv files in data directory: ['gapminder_all.csv', 'gapminder_gdp_africa.csv', 'gapminder_gdp_americas.csv', 'gapminder_gdp_asia.csv', 'gapminder_gdp_europe.csv', 'gapminder_gdp_oceania.csv']

# %%
print('all ipynb files:', glob.glob('*.ipynb'))
# Out:
# all ipynb files: ['python_plotting_10052019.ipynb', 'Untitled.ipynb', 'Untitled1.ipynb']

# %%
for filename in glob.glob('gapminder_*.csv'):
    data = pandas.read_csv(filename)
    print(filename, data['gdpPercap_1952'].min())
# Out:
# gapminder_all.csv 298.8462121
# gapminder_gdp_africa.csv 298.8462121
# gapminder_gdp_americas.csv 1397.7171369999999
# gapminder_gdp_asia.csv 331.0
# gapminder_gdp_europe.csv 973.5331947999999
# gapminder_gdp_oceania.csv 10039.595640000001

# %%
import glob
import pandas
fewest = float("Inf")
for filename in glob.glob('*.csv'):
    dataframe = pandas.read_csv(filename)
    fewest = min(fewest, dataframe.shape[0])
print('smallest file has', fewest, 'records')
# Out:
# smallest file has 2 records

# %%
import glob
import pandas
fewest = float("Inf")
for filename in glob.glob('*.csv'):
    dataframe = pandas.read_csv(filename)
    print('fewest is now:', fewest)
    fewest = min(fewest, dataframe.shape[0])
print('smallest file has', fewest, 'records')
# Out:
# fewest is now: inf
# fewest is now: 142
# fewest is now: 52
# fewest is now: 25
# fewest is now: 25
# fewest is now: 25
# smallest file has 2 records

# %%
dataframe.shape
# Out:
# (2, 13)

# %%
def print_greeting():
    print('hello')

print_greeting()
# Out:
# hello

# %%
def print_date(year, month, date):
    joined = str(year) + '/'+ str(month) + '/' + str(date)
    print(joined)
    
print_date(2019, 3, 19)
# Out:
# 2019/3/19

# %%
pressure = 103.9

def adjust(t=10):
    print('t is equal to:', t)
    temperature = t * 1.43/pressure
    return temperature

# %%
adjust(240)
# Out:
# t is equal to: 240
# 3.3031761308950913

# %%
help(adjust)
# Out:
# Help on function adjust in module __main__:
#
# adjust(t=10)

# %%
 limit = 100

def clip(value):
    return min(max(0.0, value), limit) 

value=-22.5
print(clip(value))
# Out:
# 0.0
